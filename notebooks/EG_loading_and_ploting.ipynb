# %%
using LinearAlgebra, Graphs, Plots, DelimitedFiles
include("../src/spectral_drawing_utils.jl")

A = readdlm("../data/graph_442.mat", Int64)
n = size(A)[1]
G = SimpleGraph{Int64}(A)

AEIG = eigen(A)
# Out:
# Eigen{Float64, Float64, Matrix{Float64}, Vector{Float64}}
# values:
# 5-element Vector{Float64}:
#  -1.9999999999999987
#  -1.2360679774997871
#  -5.551115078004189e-17
#   2.220446049250313e-16
#   3.23606797749979
# vectors:
# 5×5 Matrix{Float64}:
#   0.5  -0.262866  -0.707107      4.57967e-16  -0.425325
#  -0.5  -0.262866   1.38778e-16   0.707107     -0.425325
#  -0.5  -0.262866  -3.05311e-16  -0.707107     -0.425325
#   0.5  -0.262866   0.707107     -3.33067e-16  -0.425325
#   0.0   0.850651   0.0           0.0          -0.525731

# %%
X = AEIG.vectors[:,3:4]
fig = plot()
GraphVectsPlot(G, X)

# %%
X = AEIG.vectors[:,2:4]
anim = @animate for i=1:36
    plot(camera = (10i,30))
    GraphVectsPlot(G, X)
end
gif(anim, "../out/graph_442.gif", fps = 8)
# Out:
# [ Info: Saved animation to /home/jose/Desktop/UMAG/2025_II/SpectralGraphs/SpectralDrawingsL1/out/graph_442.gif
# Plots.AnimatedGif("/home/jose/Desktop/UMAG/2025_II/SpectralGraphs/SpectralDrawingsL1/out/graph_442.gif")
